# %%
from pathlib import Path
import requests

DATA_PATH = Path("data")
PATH = DATA_PATH / "mnist"

PATH.mkdir(parents=True, exist_ok=True)

URL = "http://deeplearning.net/data/mnist/"
FILENAME = "mnist.pkl.gz"

if not (PATH / FILENAME).exists():
        content = requests.get(URL + FILENAME).content
        (PATH / FILENAME).open("wb").write(content)

# %%
import pickle
import gzip

with gzip.open((PATH / FILENAME).as_posix(), "rb") as f:
        ((x_train, y_train), (x_valid, y_valid), _) = pickle.load(f, encoding="latin-1")

# %%
import pandas as pd
import lightgbm as lgb
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score
from sklearn import datasets

# %%
import time

# %%
tt = time.time()
# 转换为Dataset数据格式
train_data = lgb.Dataset(x_train, label=y_train)
validation_data = lgb.Dataset(x_valid, label=y_valid)

# 参数
params = {
    'learning_rate': 0.1,
    'lambda_l1': 0.1,
    'lambda_l2': 0.2,
    'max_depth': 4,
    'objective': 'multiclass',  # 目标函数
    'num_class': 10,
}
# 模型训练
gbm = lgb.train(params, train_data, valid_sets=[validation_data])

# 模型预测
y_pred = gbm.predict(x_valid)
#print(y_pred)
y_pred = [list(x).index(max(x)) for x in y_pred]
print(y_pred)

# 模型评估
print(accuracy_score(y_valid, y_pred))
print('Time used: {} sec'.format(time.time()-tt))
# Out:
# [1]	valid_0's multi_logloss: 2.02436
# [2]	valid_0's multi_logloss: 1.82194
# [3]	valid_0's multi_logloss: 1.65978
# [4]	valid_0's multi_logloss: 1.52579
# [5]	valid_0's multi_logloss: 1.41207
# [6]	valid_0's multi_logloss: 1.31297
# [7]	valid_0's multi_logloss: 1.22754
# [8]	valid_0's multi_logloss: 1.14996
# [9]	valid_0's multi_logloss: 1.08022
# [10]	valid_0's multi_logloss: 1.01926
# [11]	valid_0's multi_logloss: 0.961815
# [12]	valid_0's multi_logloss: 0.912
# [13]	valid_0's multi_logloss: 0.864139
# [14]	valid_0's multi_logloss: 0.822687
# [15]	valid_0's multi_logloss: 0.784225
# [16]	valid_0's multi_logloss: 0.748474
# [17]	valid_0's multi_logloss: 0.71566
# [18]	valid_0's multi_logloss: 0.68534
# [19]	valid_0's multi_logloss: 0.656782
# [20]	valid_0's multi_logloss: 0.631019
# [21]	valid_0's multi_logloss: 0.60703
# [22]	valid_0's multi_logloss: 0.584541
# [23]	valid_0's multi_logloss: 0.562499
# [24]	valid_0's multi_logloss: 0.542996
# [25]	valid_0's multi_logloss: 0.524052
# [26]	valid_0's multi_logloss: 0.506888
# [27]	valid_0's multi_logloss: 0.491132
# [28]	valid_0's multi_logloss: 0.47574
# [29]	valid_0's multi_logloss: 0.462273
# [30]	valid_0's multi_logloss: 0.449001
# [31]	valid_0's multi_logloss: 0.436328
# [32]	valid_0's multi_logloss: 0.423803
# [33]	valid_0's multi_logloss: 0.412479
# [34]	valid_0's multi_logloss: 0.401206
# [35]	valid_0's multi_logloss: 0.390846
# [36]	valid_0's multi_logloss: 0.380796
# [37]	valid_0's multi_logloss: 0.371446
# [38]	valid_0's multi_logloss: 0.36245
# [39]	valid_0's multi_logloss: 0.354607
# [40]	valid_0's multi_logloss: 0.346719
# [41]	valid_0's multi_logloss: 0.339669
# [42]	valid_0's multi_logloss: 0.33254
# [43]	valid_0's multi_logloss: 0.326202
# [44]	valid_0's multi_logloss: 0.320238
# [45]	valid_0's multi_logloss: 0.314415
# [46]	valid_0's multi_logloss: 0.308312
# [47]	valid_0's multi_logloss: 0.302763
# [48]	valid_0's multi_logloss: 0.297849
# [49]	valid_0's multi_logloss: 0.292365
# [50]	valid_0's multi_logloss: 0.287133
# [51]	valid_0's multi_logloss: 0.282506
# [52]	valid_0's multi_logloss: 0.277647
# [53]	valid_0's multi_logloss: 0.273274
# [54]	valid_0's multi_logloss: 0.26878
# [55]	valid_0's multi_logloss: 0.264224
# [56]	valid_0's multi_logloss: 0.260232
# [57]	valid_0's multi_logloss: 0.256584
# [58]	valid_0's multi_logloss: 0.252869
# [59]	valid_0's multi_logloss: 0.249502
# [60]	valid_0's multi_logloss: 0.246182
# [61]	valid_0's multi_logloss: 0.242798
# [62]	valid_0's multi_logloss: 0.239485
# [63]	valid_0's multi_logloss: 0.236539
# [64]	valid_0's multi_logloss: 0.233411
# [65]	valid_0's multi_logloss: 0.230729
# [66]	valid_0's multi_logloss: 0.227847
# [67]	valid_0's multi_logloss: 0.225002
# [68]	valid_0's multi_logloss: 0.222428
# [69]	valid_0's multi_logloss: 0.219634
# [70]	valid_0's multi_logloss: 0.217376
# [71]	valid_0's multi_logloss: 0.21435
# [72]	valid_0's multi_logloss: 0.212225
# [73]	valid_0's multi_logloss: 0.210284
# [74]	valid_0's multi_logloss: 0.20814
# [75]	valid_0's multi_logloss: 0.205888
# [76]	valid_0's multi_logloss: 0.203773
# [77]	valid_0's multi_logloss: 0.201741
# [78]	valid_0's multi_logloss: 0.199961
# [79]	valid_0's multi_logloss: 0.19785
# [80]	valid_0's multi_logloss: 0.195576
# [81]	valid_0's multi_logloss: 0.194029
# [82]	valid_0's multi_logloss: 0.192211
# [83]	valid_0's multi_logloss: 0.190547
# [84]	valid_0's multi_logloss: 0.188613
# [85]	valid_0's multi_logloss: 0.186925
# [86]	valid_0's multi_logloss: 0.185142
# [87]	valid_0's multi_logloss: 0.183453
# [88]	valid_0's multi_logloss: 0.181683
# [89]	valid_0's multi_logloss: 0.180282
# [90]	valid_0's multi_logloss: 0.178903
# [91]	valid_0's multi_logloss: 0.177326
# [92]	valid_0's multi_logloss: 0.17598
# [93]	valid_0's multi_logloss: 0.174781
# [94]	valid_0's multi_logloss: 0.173287
# [95]	valid_0's multi_logloss: 0.171668
# [96]	valid_0's multi_logloss: 0.170674
# [97]	valid_0's multi_logloss: 0.16939
# [98]	valid_0's multi_logloss: 0.168381
# [99]	valid_0's multi_logloss: 0.167165
# [100]	valid_0's multi_logloss: 0.165996
# [3, 8, 6, 9, 6, 9, 5, 3, 8, 4, 5, 2, 3, 8, 4, 8, 1, 5, 0, 5, 9, 7, 4, 1, 0, 3, 0, 6, 2, 9, 9, 4, 1, 3, 6, 8, 0, 7, 7, 6, 8, 9, 0, 3, 8, 3, 7, 7, 8, 4, 4, 1, 2, 9, 8, 1, 1, 0, 6, 6, 5, 0, 1, 1, 7, 2, 7, 3, 1, 4, 0, 5, 0, 6, 9, 7, 6, 8, 3, 9, 4, 0, 6, 1, 9, 2, 6, 3, 9, 4, 4, 5, 6, 6, 1, 7, 2, 8, 6, 9, 7, 0, 9, 1, 6, 2, 8, 3, 6, 4, 9, 5, 8, 
 7, 7, 7, 1, 8, 8, 9, 0, 3, 2, 6, 2, 0, 2, 3, 8, 6, 6, 4, 3, 8, 8, 4, 0, 5, 0, 7, 1, 5, 6, 6, 5, 0, 9, 3, 2, 8, 9, 4, 8, 8, 8, 3, 6, 1, 4, 1, 1, 5, 1, 9, 5, 4, 2, 3, 5, 0, 3, 4, 2, 4, 4, 0, 8, 9, 3, 6, 4, 9, 8, 2, 5, 2, 6, 1, 5, 7, 1, 9, 7, 5, 9, 1, 0, 1, 4, 9, 0, 8, 7, 6, 7, 6, 5, 9, 5, 0, 1, 0, 8, 0, 9, 1, 7, 8, 0, 4, 6, 6, 4, 8, 0, 8, 9, 2, 9, 6, 2, 3, 7, 2, 8, 4, 8, 0, 4, 9, 8, 0, 3,  ...
# 0.9568
# Time used: 74.20362401008606 sec

# %%
import xgboost as xgb

# %%
tt = time.time()
#dmatrix 格式 在xgboost当中运行速度更快，性能更好。
dtrain = xgb.DMatrix(x_train, label=y_train)
dtest = xgb.DMatrix(x_valid, label=y_valid)

xgb_params = {
    'seed': 0,
    'eta': 0.1,
    'colsample_bytree': 0.5,
    'silent': 1,
    'subsample': 0.5,
    'objective': 'multi:softmax',
    'num_class':10,
    'max_depth': 4,
    'min_child_weight': 3
}


bst = xgb.train(xgb_params, dtrain, 100, evals=[(dtrain,'train'), (dtest,'test')])

preds = bst.predict(dtest)
auc = accuracy_score(y_valid, preds)

print(auc)
print('Time used: {} sec'.format(time.time()-tt))
# Out:
# [0]	train-merror:0.24184	test-merror:0.2277
# [1]	train-merror:0.18706	test-merror:0.174
# [2]	train-merror:0.16302	test-merror:0.1559
# [3]	train-merror:0.14826	test-merror:0.1422
# [4]	train-merror:0.13994	test-merror:0.133
# [5]	train-merror:0.13582	test-merror:0.1286
# [6]	train-merror:0.12844	test-merror:0.1213
# [7]	train-merror:0.12242	test-merror:0.118
# [8]	train-merror:0.11972	test-merror:0.1146
# [9]	train-merror:0.11554	test-merror:0.1126
# [10]	train-merror:0.11258	test-merror:0.1094
# [11]	train-merror:0.11028	test-merror:0.1058
# [12]	train-merror:0.1083	test-merror:0.1043
# [13]	train-merror:0.10516	test-merror:0.0999
# [14]	train-merror:0.10314	test-merror:0.0983
# [15]	train-merror:0.1008	test-merror:0.0964
# [16]	train-merror:0.10018	test-merror:0.0964
# [17]	train-merror:0.09894	test-merror:0.0953
# [18]	train-merror:0.09682	test-merror:0.0951
# [19]	train-merror:0.09502	test-merror:0.0934
# [20]	train-merror:0.09294	test-merror:0.0917
# [21]	train-merror:0.09166	test-merror:0.09
# [22]	train-merror:0.08956	test-merror:0.0894
# [23]	train-merror:0.08808	test-merror:0.0879
# [24]	train-merror:0.08648	test-merror:0.0862
# [25]	train-merror:0.0855	test-merror:0.0853
# [26]	train-merror:0.08338	test-merror:0.0836
# [27]	train-merror:0.08254	test-merror:0.0828
# [28]	train-merror:0.08164	test-merror:0.0814
# [29]	train-merror:0.08046	test-merror:0.0805
# [30]	train-merror:0.07864	test-merror:0.0802
# [31]	train-merror:0.0777	test-merror:0.0788
# [32]	train-merror:0.07694	test-merror:0.0784
# [33]	train-merror:0.07556	test-merror:0.0779
# [34]	train-merror:0.07438	test-merror:0.0768
# [35]	train-merror:0.073	test-merror:0.0759
# [36]	train-merror:0.07158	test-merror:0.0755
# [37]	train-merror:0.07054	test-merror:0.0737
# [38]	train-merror:0.06958	test-merror:0.073
# [39]	train-merror:0.06842	test-merror:0.0722
# [40]	train-merror:0.06758	test-merror:0.071
# [41]	train-merror:0.06638	test-merror:0.0701
# [42]	train-merror:0.06532	test-merror:0.0695
# [43]	train-merror:0.06432	test-merror:0.0689
# [44]	train-merror:0.06306	test-merror:0.0673
# [45]	train-merror:0.06214	test-merror:0.0662
# [46]	train-merror:0.0612	test-merror:0.0659
# [47]	train-merror:0.06028	test-merror:0.0645
# [48]	train-merror:0.05926	test-merror:0.0637
# [49]	train-merror:0.0585	test-merror:0.0632
# [50]	train-merror:0.05766	test-merror:0.063
# [51]	train-merror:0.05682	test-merror:0.0626
# [52]	train-merror:0.05592	test-merror:0.0615
# [53]	train-merror:0.05542	test-merror:0.0605
# [54]	train-merror:0.05448	test-merror:0.0598
# [55]	train-merror:0.05392	test-merror:0.0596
# [56]	train-merror:0.05278	test-merror:0.0583
# [57]	train-merror:0.05258	test-merror:0.0582
# [58]	train-merror:0.05178	test-merror:0.0577
# [59]	train-merror:0.05114	test-merror:0.0568
# [60]	train-merror:0.0504	test-merror:0.0563
# [61]	train-merror:0.04978	test-merror:0.0554
# [62]	train-merror:0.04894	test-merror:0.054
# [63]	train-merror:0.04848	test-merror:0.0538
# [64]	train-merror:0.0478	test-merror:0.0539
# [65]	train-merror:0.04724	test-merror:0.0541
# [66]	train-merror:0.04686	test-merror:0.0534
# [67]	train-merror:0.04624	test-merror:0.0529
# [68]	train-merror:0.04572	test-merror:0.0524
# [69]	train-merror:0.04526	test-merror:0.0526
# [70]	train-merror:0.0447	test-merror:0.0518
# [71]	train-merror:0.04424	test-merror:0.0515
# [72]	train-merror:0.04352	test-merror:0.0508
# [73]	train-merror:0.0428	test-merror:0.0507
# [74]	train-merror:0.04234	test-merror:0.0499
# [75]	train-merror:0.0418	test-merror:0.0497
# [76]	train-merror:0.0417	test-merror:0.0487
# [77]	train-merror:0.04126	test-merror:0.0482
# [78]	train-merror:0.04096	test-merror:0.0479
# [79]	train-merror:0.0402	test-merror:0.0474
# [80]	train-merror:0.03972	test-merror:0.0465
# [81]	train-merror:0.03924	test-merror:0.0467
# [82]	train-merror:0.03878	test-merror:0.0469
# [83]	train-merror:0.03838	test-merror:0.0465
# [84]	train-merror:0.03778	test-merror:0.0459
# [85]	train-merror:0.03736	test-merror:0.0455
# [86]	train-merror:0.03682	test-merror:0.0452
# [87]	train-merror:0.03638	test-merror:0.0445
# [88]	train-merror:0.03606	test-merror:0.0439
# [89]	train-merror:0.03564	test-merror:0.0433
# [90]	train-merror:0.03514	test-merror:0.0428
# [91]	train-merror:0.0345	test-merror:0.0427
# [92]	train-merror:0.03406	test-merror:0.0426
# [93]	train-merror:0.03368	test-merror:0.0424
# [94]	train-merror:0.0336	test-merror:0.0421
# [95]	train-merror:0.03314	test-merror:0.0418
# [96]	train-merror:0.0327	test-merror:0.0416
# [97]	train-merror:0.03252	test-merror:0.0416
# [98]	train-merror:0.03242	test-merror:0.0414
# [99]	train-merror:0.0318	test-merror:0.041
# 0.959
# Time used: 1098.1514909267426 sec
